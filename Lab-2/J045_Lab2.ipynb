# %%
from gensim.test.utils import common_texts
from gensim.models import Word2Vec
import numpy as np, pandas as pd
from nltk.corpus import stopwords
import gensim.downloader
from nltk.tokenize import word_tokenize

# %%
def checkForeignChars(token: str):
    for letter in set(token):
        if ord(letter) not in range(65, 65+26) and ord(letter) not in range(97, 97+26):
            return True
    return False

# %%
model = Word2Vec(sentences=common_texts, vector_size=100, window=5, min_count=1, workers=4)

# %%
data = pd.read_csv('./IMDB Dataset.csv')

# %%
subset = data.iloc[:10000]

# %%
all_tokens = []

for text in subset['review']:
    all_tokens.extend(word_tokenize(text))

all_tokens = list(set([t.lower().strip('.').strip(',').strip(' ') for t in all_tokens]))

# %%
for t in all_tokens:
    if checkForeignChars(t):
        all_tokens.remove(t)

# %%
'idk.'.strip('.')
# Out:
# 'idk'

# %%
all_tokens
# Out:
# ['',
#  'patent',
#  'thorpe',
#  'proportionate',
#  'barron',
#  'evaluate',
#  'subdue',
#  'sabre',
#  'veeringly',
#  'spectacled',
#  'berseker',
#  'uncovered',
#  'criticise',
#  'authorities',
#  'nailing',
#  'lifetimes',
#  'draza',
#  'clans',
#  'philbin',
#  'samson',
#  'consumable',
#  'doting',
#  'deterioration',
#  'dreaded',
#  'latham',
#  'steely',
#  'prefix',
#  'vinci',
#  'ore',
#  'viking',
#  'saif',
#  'alok',
#  'honoria',
#  'whiny',
#  'abhisheh',
#  'serb',
#  'beecher',
#  'everywhere',
#  'sandblaster',
#  'mcneil',
#  'stigma',
#  'reinvention',
#  'tailing',
#  'smarmiess',
#  'rakkie',
#  'salient',
#  'potholes',
#  'anachronic',
#  'proclaimed',
#  'dispensed',
#  'zarkorr',
#  'glasgow',
#  'modular',
#  'biko',
#  'jupiter',
#  'manageable',
#  'glossed',
#  'kali',
#  'polonius',
#  'mother',
#  'hilltop',
#  'searing',
#  'scopophilia',
#  'bandini',
#  'umber',
#  'toms',
#  'consensus-based',
#  'credible',
#  'deserve',
#  'ruuun',
#  'stormer',
#  'badboys',
#  'orbs',
#  "'doctor",
#  'joel',
#  'obscure',
#  "l'intrus",
#  'unmissable',
#  'unsuspensful',
#  'petite',
#  'ludwig',
#  'bloodbaths',
#  'popularize',
#  'thety',
#  'macaulay',
#  'plasticy',
#  'irresistable',
#  'clark',
#  'kader',
#  'handicaps',
#  'sinker',
#  'diplodocus',
#  'abstractions',
#  'miscast',
#  'sevizia',
#  'oberon',
#  'blob',
#  'lundgren',
#  'caliber',
#  'fountain',
#  "'em",
#  'nd',
#  'sparsely',
#  'deepest',
#  'consulate',
#  'croakers',
#  'loydd',
#  'boltay',
#  'underestimate',
#  'grahame',
#  'jostled',
#  'unnervingly',
#  'neema',
#  'damien',
#  'bury',
#  'fearlessness',
#  'groupthink',
#  'unfounded',
#  'deemed',
#  'cult',
#  'overhyped',
#  "'major",
#  'spooky',
#  'sceenplay',
#  'evaporated',
#  'jurgen',
#  'extravagant',
#  'endfield',
#  'before-',
#  'anarchist',
#  'shifts',
#  'unemotionally',
#  'amzy',
#  'offices',
#  'unstructured',
#  'flimsy',
#  'ruling',
#  'meaner',
#  'concernened',
#  'roster',
#  'liberated',
#  'chas',
#  'sonali',
#  'nor',
#  'grauer',
#  'trills',
#  'lines/plot',
#  'mounting',
#  'piloted',
#  'weilded',
#  'piercings',
#  'dysfunctional',
#  'loew',
#  'keatons',
#  'moroco',
#  'louis',
#  'contribute',
#  'capsules',
#  'ashe',
#  'trawling',
#  'aiming',
#  'oppositeness',
#  'shim',
#  'jory',
#  'checked',
#  'moan',
#  'foundling',
#  'wheedling',
#  'homicidally',
#  'materialize',
#  'serato',
#  'duchenne',
#  'towel',
#  'thje',
#  'persisentily',
#  'syndicated',
#  'haply',
#  'casualness',
#  'raggedys',
#  'rallying',
#  'nam',
#  'disorganized',
#  'jaeckel',
#  'copious',
#  'coherency',
#  'bendorf',
#  'rayon',
#  'instant',
#  'armored',
#  'stove',
#  'coronary',
#  'reggiani',
#  'weep',
#  'coupe',
#  'vacillate',
#  'awww',
#  'macnee',
#  'exectution',
#  'rigged',
#  'gauge',
#  'dissatisfyingly',
#  'flamethrower',
#  'inbreeds',
#  'jaffa',
#  'uhh',
#  'bolting',
#  'out-of-body',
#  'satisfactory',
#  'communism',
#  'boxoffice',
#  'treatise',
#  'negative',
#  'weirdo',
#  'grim',
#  'eyelid',
#  'astaire',
#  'judgement',
#  'scuttle',
#  'frazzled',
#  'unsuspecting',
#  'onasis',
#  'similiar',
#  'inge',
#  'recommand',
#  'groups',
#  'alumnus',
#  'scorcese',
#  'sportswear',
#  'abel',
#  'physics',
#  'hoodies',
#  'brightons',
#  'rifkin',
#  'dispatches',
#  'unleashes',
#  'commissioner',
#  'knocked',
#  'pleasence',
#  'pickpocket',
#  'barbells',
#  'eckstrom',
#  'enjoying',
#  'garmes',
#  'catches',
#  'aerial',
#  'ivanova',
#  'sablok',
#  'terminator',
#  'beast',
#  'kaufmann',
#  'pardon',
#  'amatuer',
#  'instructor',
#  'droppingly',
#  'codgers',
#  "shining'",
#  'few',
#  'genesis',
#  'utans',
#  'librarians',
#  'garofalo',
#  'shielding',
#  'per',
#  'correlation',
#  'drones',
#  'manged',
#  'boxers',
#  'embarcadero',
#  'yun',
#  'juan',
#  'spooking',
#  'watering',
#  'creature',
#  'following',
#  'neither',
#  'absorbed',
#  'attitudes',
#  'smacked',
#  'surprised',
#  'porshe',
#  'elkanah',
#  'dominatrix',
#  'menephta',
#  'fame-identity',
#  'fitting',
#  'voracious',
#  'xiong',
#  'liebmann',
#  'huston',
#  'zombied',
#  'cabbie',
#  'probes',
#  'oneself',
#  'rennahan',
#  'permeate',
#  'kep',
#  'employing',
#  'celebrations',
#  'horseman',
#  'wournow',
#  'bjm',
#  'nonspecific',
#  'xxxxviii',
#  'reflected',
#  'mongolian',
#  'mcgrew',
#  'hillary',
#  'stewert',
#  '1992',
#  'linguistically',
#  'loot',
#  'gambon',
#  'playmate',
#  'doodads',
#  'straightforward',
#  'kinked',
#  'fog',
#  'dvorak',
#  'bock',
#  'outspoken',
#  'sexes',
#  'slaussen',
#  'staden',
#  'generall',
#  'armchair',
#  'seiner',
#  'chirpy',
#  'disappoints',
#  'incurred',
#  'integrate',
#  'homemade',
#  'neighborrhood',
#  'yanked',
#  'whackjobs',
#  'vampire',
#  'levelled',
#  "'faith",
#  'milk',
#  'yarborough',
#  'parley',
#  'riddled',
#  'approach',
#  'deserts',
#  'shrewish',
#  'd.r',
#  'moeller',
#  'dragon',
#  'bordeaux',
#  'heroism',
#  'fleetingly',
#  'rashomon',
#  'leighton',
#  'antonellina',
#  'deserving',
#  "'die",
#  'cannibals',
#  'clasping',
#  'practical',
#  'plump',
#  'cinnamon',
#  'leeves',
#  'perplexing',
#  'relives',
#  'awry',
#  'sluty',
#  'bore',
#  'metropolitan',
#  'dodgers',
#  'leitmotif',
#  'innately',
#  'dowagers',
#  'bianca',
#  'mansion',
#  'inxs',
#  'deutschland',
#  'ambiance',
#  'everly',
#  'gump-like',
#  'hydroplane',
#  'ibbs',
#  '^_^',
#  'antithesis',
#  'robespierre',
#  'moorican',
#  'zealous',
#  'ship-to-ship',
#  'murdoch',
#  'championship',
#  'carnival',
#  'accusations',
#  'unfitting',
#  'lololol',
#  'billie',
#  'takings',
#  'makeshift',
#  'orientation',
#  "'electrical",
#  'clearer',
#  'underacts',
#  'sidewinder',
#  'berber',
#  'moustache',
#  'romances',
#  'skyggen',
#  'copycat',
#  'protestant',
#  'corsair',
#  'millar',
#  'latidos',
#  'stickers',
#  'janis',
#  'darker',
#  'loyalties',
#  'barn',
#  'paleontologist',
#  'deflect',
#  'insinuates',
#  'heart-shaped',
#  'wisconsin',
#  'unbeknownest',
#  'cutsey',
#  'napoleon',
#  'differentiating',
#  'intertwines',
#  'unperturbed',
#  'palminteri',
#  'starving',
#  'nolte',
#  'balonga',
#  'beirut',
#  'brasco',
#  'writ',
#  'slowdown',
#  'starlets',
#  'unwatchability',
#  'gung-ho',
#  'kart',
#  'convulsed',
#  'ji-hyun',
#  'laugh',
#  'trent',
#  'frodo',
#  'scumbags',
#  'pestario',
#  'teletubbies',
#  'abundantly',
#  'dobie',
#  'heartwrenching',
#  'sonatine',
#  'flocker',
#  'ingmar',
#  'poems',
#  'personating',
#  'weakest',
#  'conti',
#  'seller',
#  'hacks',
#  'radioactive',
#  'protocol',
#  'heya',
#  'gambles',
#  'viviane',
#  'increasing',
#  'recapture',
#  'bleep',
#  'eighteen',
#  'enter',
#  'cashman',
#  'underarms',
#  'epcot',
#  'purposely',
#  'mesmerize',
#  'triumphing',
#  'moulds',
#  'steege',
#  'aperture',
#  'broods',
#  'gypo',
#  'independents',
#  'disintegrates',
#  'robson',
#  'brooding',
#  'groan',
#  'sanderson',
#  'drive',
#  'frog',
#  'ascent',
#  'belts',
#  'shipwrecks',
#  'syndication',
#  'poultry',
#  'curio',
#  'electrocute',
#  'kurt',
#  'necessities',
#  'upgrading',
#  'pyrenees',
#  'parenthood',
#  'veracity',
#  'stargher',
#  'gourmets',
#  'intellegent',
#  'kazuko',
#  'maybee',
#  'mice',
#  'neo-nazism',
#  'recollected',
#  'roxanne',
#  'bosch',
#  'reconstructive',
#  'khazei',
#  'maples',
#  'rhode',
#  'trusting',
#  'accurately',
#  'mismatched',
#  'sugarcoated',
#  'satans',
#  'incomprehensibly',
#  'moralistic',
#  'broomsticks',
#  'unevenness',
#  'nervo',
#  'poupaud',
#  'playboy',
#  'wildness',
#  'spartacus',
#  'unfocused',
#  'hiding',
#  'sickening',
#  'rotted',
#  'hainey',
#  'weeper',
#  'physicalized',
#  'employes',
#  'caimano',
#  'bohringer',
#  'longest',
#  'stuckey',
#  'hacksaws',
#  'undetermined',
#  'sharpshooter',
#  'nahin',
#  'pits',
#  'chances',
#  'excursion',
#  'chiefly',
#  'whanganui',
#  'lapd',
#  'conquest',
#  'atan',
#  'mae',
#  'concurred',
#  'chirping',
#  'meld',
#  'mummified',
#  'massen',
#  'defendant',
#  'well-argued',
#  'aims',
#  'osmond',
#  'degeneracy',
#  'hulu',
#  'charitably',
#  'gramm',
#  'cowards',
#  'taints',
#  'creativeness',
#  'fandango',
#  'obabakoak',
#  'weirdly',
#  'carraway',
#  'ivar',
#  'spottiswoode',
#  'depression',
#  'genius',
#  'touchingly',
#  'glorifying',
#  'wrenchingly',
#  'euro-cult',
#  'grateful',
#  'indisputable',
#  'see.jennifer',
#  'cillian',
#  'jfk',
#  'ramullah',
#  'kurds',
#  'cliché',
#  'flashier',
#  'inexperienced',
#  'beguiles',
#  'cause',
#  'feels',
#  'lugs',
#  'gens',
#  'staging',
#  'nordberg',
#  'killzone',
#  'circumlocutions',
#  'cruising',
#  'feature',
#  'chubb',
#  'kiya',
#  'larter',
#  'ferox',
#  'stinkbomb',
#  'stare-downs',
#  'worm',
#  'renamed',
#  'presidency',
#  'carves',
#  'formidable',
#  'ulliel',
#  'baghdad',
#  'effervescent',
#  'resists',
#  'seemed',
#  'ester',
#  'invigorated',
#  'pornography',
#  'today',
#  'knockin',
#  'anycow',
#  'forgive',
#  'epidemic',
#  'friendkin',
#  'listener',
#  'giddiness',
#  'mailbox',
#  'machine',
#  '3-4',
#  'lanscaping',
#  'realistically',
#  'bolla',
#  'championships',
#  'laboratory',
#  'fdfs',
#  'g8',
#  'hetero',
#  'unauthentic',
#  'pleshette',
#  'butchers',
#  'fulfill',
#  'rows',
#  'awoke',
#  'chet',
#  'military-like',
#  'confronts',
#  'whitley',
#  'kiddypr0n',
#  'caps',
#  'mcgregor',
#  'pathetic',
#  'encounters',
#  'spud',
#  'mosad',
#  'lois',
#  'mcconaughey',
#  'brain-numbing',
#  'felsh',
#  'obedience',
#  'wholesome',
#  'japanese',
#  'mdma',
#  'renal',
#  'mastering',
#  'boundless',
#  'genital',
#  'crumbling',
#  'lucius',
#  'demolitionist',
#  'bought',
#  'pathetically',
#  'saratoge',
#  'hartnett',
#  'bocanegra',
#  'alb',
#  'accepted',
#  'name-order',
#  'moderate',
#  'interlenghi',
#  'zombification',
#  'vampires',
#  'musically',
#  'bounded',
#  'explosives',
#  'factories',
#  'identical',
#  'westpoint',
#  'flagrantly',
#  'attached',
#  'conveying',
#  'methods',
#  'blackmailers',
#  'singleton',
#  'naish',
#  'concorde/new',
#  'panties',
#  'chipettes',
#  'raab',
#  'absent-minded',
#  'ahalf',
#  'violeta',
#  'nicodemus',
#  'tunisia',
#  'kabinett',
#  'repertory',
#  'indigenous',
#  'subjugated',
#  'orchestra',
#  'hammerstein',
#  'dishonorable',
#  'fenton',
#  'ceasarean',
#  'scolding',
#  'freak',
#  'hero',
#  'transmitted',
#  'directionless',
#  'airheads',
#  'luminiscent',
#  'tudor',
#  'over-dramatised',
#  'soorya',
#  'ignominious',
#  'diviner',
#  'moonbeam',
#  'fbl',
#  'gyrating',
#  'andalusian',
#  'incoherences',
#  '2000',
#  'code',
#  'daintily',
#  'slithers',
#  'proclaiming',
#  'remotely',
#  'female',
#  'plastered',
#  'wailing',
#  'tequila',
#  'capitalise',
#  'brumes',
#  '99.9999',
#  'viennese',
#  'scientist',
#  'clairvoyance',
#  'spanning',
#  'grinders',
#  'gautum',
#  'poster',
#  'naor',
#  'bashes',
#  'berkoff',
#  'storyboarding',
#  'satanic/giallo',
#  'tassel',
#  'loss',
#  'fifth',
#  'greico',
#  'coogan',
#  'noire',
#  'cugat',
#  'pinging',
#  'doig',
#  'attain',
#  'sequins',
#  'sister-in-law',
#  'knowing',
#  'esthetically',
#  'decently',
#  'exposure',
#  'unicorns',
#  'unending',
#  'patio',
#  'not-too-convincing',
#  'tomanovich',
#  'bogeymen',
#  'diabolically',
#  'jacket',
#  'jumbo',
#  'embodiment',
#  'submarine',
#  'screamers',
#  'century',
#  'stupidity',
#  'ullmer',
#  'wahee',
#  'paralysed',
#  'joggers',
#  'fallacy',
#  'retract',
#  'ferrell',
#  'wks',
#  'speckled',
#  'joyeux',
#  'golightly',
#  'zeb',
#  'deviousness',
#  'film-the',
#  'marv',
#  'halloween-style',
#  'mishandled',
#  'effortlessly',
#  'insider',
#  'nicki',
#  'coop',
#  'unequal',
#  'quite',
#  'atlantic',
#  'qualifications',
#  'buck',
#  'rework',
#  'dwellers',
#  'yemen',
#  'passing',
#  'denigration',
#  'stern-faced',
#  'chand',
#  'lizabeth',
#  'kgb',
#  'untied',
#  'learned',
#  'memo',
#  'bemoaning',
#  'hughly',
#  'adaption',
#  'deducted',
#  'striesand',
#  'miltonesque',
#  'entering',
#  'inspirational',
#  'mess',
#  'somewhere',
#  'cheques',
#  'shockingly',
#  'apalling',
#  'hsiao',
#  'flavors',
#  'slo-mo',
#  'reject',
#  'frontbenchers',
#  'wisps',
#  'elia',
#  'clarification',
#  'winship',
#  'commits',
#  'predominated',
#  'moses',
#  'nft',
#  'tissues',
#  'piddling',
#  'in-crowd',
#  'rains',
#  'durbridge',
#  'ladylike',
#  'strongpoints',
#  'fails',
#  'duty',
#  'dismiss',
#  'naughty',
#  'mediation',
#  'plainfield',
#  'explicit',
#  'westlake',
#  'secreto',
#  'slade',
#  'hildegard',
#  'tangi',
#  'favo',
#  'dispenza',
#  'pratt-another',
#  '200',
#  'milktoast',
#  'kuriyama',
#  'neurons',
#  'lucci',
#  'glove',
#  'brittany',
#  'real-like',
#  'grass',
#  'slob',
#  'susana',
#  'seniors',
#  'shroder',
#  'delving',
#  "'snapshot",
#  'marceau',
#  'keyshia',
#  'sentenced',
#  'paltry',
#  'brandishing',
#  'command',
#  'xi',
#  'theyre',
#  'loosen',
#  'resurfaced',
#  'specified',
#  'garryjohal',
#  'flunky',
#  'cereal',
#  'firecracker',
#  'disproportional',
#  'autobiographical',
#  'demarco',
#  'passes',
#  'pencil',
#  'zippo',
#  'squad',
#  'compromise',
#  'nail-bitingly',
#  'bachan',
#  'roasario',
#  'nouveau',
#  'copying',
#  'inquired',
#  'eko',
#  'rolls',
#  'fixation',
#  'rode',
#  'kid-focused',
#  'shootouts',
#  'elongating',
#  'big-freaking',
#  'thied',
#  'sizzled',
#  'christian',
#  'enormeous',
#  'insert',
#  'elvis',
#  'wasps',
#  'gingko',
#  'spoilt',
#  'yoshitaka',
#  'hand-selected',
#  'steeped',
#  'davidians',
#  'wipes',
#  'frankenstien',
#  'scrolled',
#  'treacly',
#  'rex',
#  'peak…',
#  'excel',
#  'ehren',
#  'wachowski',
#  'robison',
#  'dewey',
#  "'bombadier",
#  'allude',
#  'melons',
#  'canyons',
#  'existing',
#  'condescendingly',
#  'battalion',
#  'underscore',
#  'wood',
#  'kiddies',
#  'leiv',
#  'shelby',
#  'wussy',
#  'hooker',
#  'pbs',
#  'inequality',
#  'rolfe',
#  'minority',
#  'humdrum',
#  'psyching',
#  'seidelman',
#  'solonitsyn',
#  'antebellum',
#  'outlawed',
#  'clowning',
#  'palma',
#  'materially',
#  'harker',
#  'booths',
#  'truncated',
#  'slack',
#  'progressed',
#  'mid',
#  'clubbing',
#  'treatment',
#  'injections',
#  'rafe',
#  'blocks',
#  'latent',
#  'mayor',
#  'hewitt',
#  'toni',
#  'tin',
#  'kristofferson',
#  'stains',
#  'ognianova',
#  'harboring',
#  'elfriede',
#  'fuzziness',
#  'zombiefied',
#  'dostoyevsky',
#  'typewriter',
#  ...]
